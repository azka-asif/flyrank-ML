# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/azka-asif/flyrank-ML/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
#
# Refresh / Content Opportunity Scoring
#
# I chose the Refresh / Content Opportunity Scoring lane because I am interested in understanding how machine learning can help identify which pages should be prioritized for review. This approach uses the data to identify which pages may have the highest opportunity for improvement based on the observed data. This addresses the challenge of limited time and resources as it helps the editors decide which pages to review first.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
#
# My work aims to improve the decision of determining which content pages should be reviewed first based on their potential for improvement. The output is intended to help content editors who can utilize the ranked list while deciding which pages to review before others. An incorrect recommendation could potentially result in the wastage of limited resources and time. Editors might spend time reviewing pages that may not need attention or they might overlook pages that may benefit from improvements.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*
#
# The starter dataset contains approximately 30,000 content pages, showing that manually reviewing every page would not be a practical decision. In the starter pipeline, the baseline rule achieved a Precision@50 of 0.240, while the Random Forest model achieved a Precision@50 of 0.740. This suggests that a learned model can produce a more useful ranking than a simple rule on this dataset.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
#
# My work will provide decision support by using observed performance signals to identify pages that potentially deserve review. The results can also show patterns in the data and help prioritize pages for further review. My work will not prove that updating a page will improve its performance, identify Google's ranking algorithm, or establish a causal relationship between any feature and future outcomes.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
